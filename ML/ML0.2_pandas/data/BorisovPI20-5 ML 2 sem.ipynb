# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Загрузка массива

# %%
myDataFrame = pd.read_csv('train.csv')
myDataFrame.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Количество измерений

# %%
myDataFrame.shape[0]
# Out:
# 891

# %% [markdown]
# Количество полей данных

# %%
myDataFrame.shape[1]
# Out:
# 12

# %%
myDataFrame.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %% [markdown]
# Тип данных каждого поля, шкала каждого поля

# %%
myDataFrame.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
myDataFrame.describe().loc[['min', 'max']]
# Out:
#      PassengerId  Survived  Pclass    Age  SibSp  Parch      Fare
# min          1.0       0.0     1.0   0.42    0.0    0.0    0.0000
# max        891.0       1.0     3.0  80.00    8.0    6.0  512.3292

# %% [markdown]
# Количество отсутствующих значений для каждого поля

# %%
myDataFrame.isna().sum(axis=0)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Количество и названия константных и уникальных полей

# %%
maskUniq = myDataFrame.nunique() == myDataFrame.shape[0]
colUniq = myDataFrame.nunique()[maskUniq].index.values
print('Количество уникальных полей: ', maskUniq.sum(),
      f'\nУникальные поля\n{colUniq}', )

maskConst = myDataFrame.nunique() == 1
colConst = myDataFrame.nunique()[maskConst].index.values
print('Количество константных полей: ', maskConst.sum(),
      f'\nКонстантные поля\n{colConst}', )
# Out:
# Количество уникальных полей:  2
# Уникальные поля
# ['PassengerId' 'Name']
# Количество константных полей:  0
# Константные поля
# []

# %% [markdown]
# Удалить из набора поля, не несущие информативной нагрузки - содержащие уникальные либо константные значения

# %%
myDataFrame = myDataFrame.drop(np.concatenate((colUniq, colConst)), axis=1) 
myDataFrame.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C
# 2   NaN        S
# 3  C123        S
# 4   NaN        S

# %% [markdown]
# Заменить возраст пассажиров на год рождения

# %%
import datetime
now = datetime.datetime.now().year

# %%
myDataFrame['Age'] = now - myDataFrame['Age']
myDataFrame
# Out:
#      Survived  Pclass     Sex     Age  SibSp  Parch            Ticket  \
# 0           0       3    male  2000.0      1      0         A/5 21171
# 1           1       1  female  1984.0      1      0          PC 17599
# 2           1       3  female  1996.0      0      0  STON/O2. 3101282
# 3           1       1  female  1987.0      1      0            113803
# 4           0       3    male  1987.0      0      0            373450
# ..        ...     ...     ...     ...    ...    ...               ...
# 886         0       2    male  1995.0      0      0            211536
# 887         1       1  female  2003.0      0      0            112053
# 888         0       3  female     NaN      1      2        W./C. 6607
# 889         1       1    male  1996.0      0      0            111369
# 890         0       3    male  1990.0      0      0            370376
#
#         Fare Cabin Embarked
# 0     7.2500   NaN        S
# 1    71.2833   C85        C
# 2     7.9250   NaN        S
# ...

# %% [markdown]
# Переименовать все названия колонок на русском языке

# %%
newColNames = {
    'Survived': 'Выжившие',
    'Pclass': 'КлассПассажира',
    'Sex': 'Пол',
    'Age': 'Возраст',
    'SibSp': 'Сибсп',
    'Parch': 'Пергамент',
    'Ticket': 'Билет',
    'Fare': 'Стоимость',
    'Cabin': 'Купе',
    'Embarked': 'Погружены',
}
myDataFrame.rename(columns=newColNames, inplace=True)
myDataFrame
# Out:
#      Выжившие  КлассПассажира     Пол  Возраст  Сибсп  Пергамент  \
# 0           0               3    male   2000.0      1          0
# 1           1               1  female   1984.0      1          0
# 2           1               3  female   1996.0      0          0
# 3           1               1  female   1987.0      1          0
# 4           0               3    male   1987.0      0          0
# ..        ...             ...     ...      ...    ...        ...
# 886         0               2    male   1995.0      0          0
# 887         1               1  female   2003.0      0          0
# 888         0               3  female      NaN      1          2
# 889         1               1    male   1996.0      0          0
# 890         0               3    male   1990.0      0          0
#
#                 Билет  Стоимость  Купе Погружены
# 0           A/5 21171     7.2500   NaN         S
# 1            PC 17599    71.2833   C85         C
# ...

# %% [markdown]
# Заменить все отсутствующие данные средним значением (в случае числового поля) либо самым распространенным в категориальных полях.

# %%
valuesToReplace = myDataFrame.mode().loc[0]
meamVal = myDataFrame.describe().loc['mean']
valuesToReplace[meamVal.index] = meamVal.values
valuesToReplace
# Out:
# Выжившие             0.383838
# КлассПассажира       2.308642
# Пол                      male
# Возраст           1992.300882
# Сибсп                0.523008
# Пергамент            0.381594
# Билет                    1601
# Стоимость           32.204208
# Купе                  B96 B98
# Погружены                   S
# Name: 0, dtype: object

# %%
maskNAN = myDataFrame.isna().sum(axis=1) != 0
myDataFrame[maskNAN]
# Out:
#      Выжившие  КлассПассажира     Пол  Возраст  Сибсп  Пергамент  \
# 0           0               3    male   2000.0      1          0
# 2           1               3  female   1996.0      0          0
# 4           0               3    male   1987.0      0          0
# 5           0               3    male      NaN      0          0
# 7           0               3    male   2020.0      3          1
# ..        ...             ...     ...      ...    ...        ...
# 884         0               3    male   1997.0      0          0
# 885         0               3  female   1983.0      0          5
# 886         0               2    male   1995.0      0          0
# 888         0               3  female      NaN      1          2
# 890         0               3    male   1990.0      0          0
#
#                 Билет  Стоимость Купе Погружены
# 0           A/5 21171     7.2500  NaN         S
# 2    STON/O2. 3101282     7.9250  NaN         S
# ...

# %%
myDataFrame = myDataFrame.fillna(valuesToReplace)

# %%
myDataFrame[maskNAN]
# Out:
#      Выжившие  КлассПассажира     Пол      Возраст  Сибсп  Пергамент  \
# 0           0               3    male  2000.000000      1          0
# 2           1               3  female  1996.000000      0          0
# 4           0               3    male  1987.000000      0          0
# 5           0               3    male  1992.300882      0          0
# 7           0               3    male  2020.000000      3          1
# ..        ...             ...     ...          ...    ...        ...
# 884         0               3    male  1997.000000      0          0
# 885         0               3  female  1983.000000      0          5
# 886         0               2    male  1995.000000      0          0
# 888         0               3  female  1992.300882      1          2
# 890         0               3    male  1990.000000      0          0
#
#                 Билет  Стоимость     Купе Погружены
# 0           A/5 21171     7.2500  B96 B98         S
# ...

# %% [markdown]
# Сохранить получившийся набор данных в формате CSV

# %%
myDataFrame.to_csv('NewData.csv', encoding="cp1251", sep=";")

# %% [markdown]
# Считать файл .xlsx в новый DataFrame

# %%
myDataFrameX = pd.read_excel('NewDataX.xlsx')
myDataFrameX
# Out:
#      Unnamed: 0  Выжившие  КлассПассажира     Пол      Возраст  Сибсп  \
# 0             0         0               3    male  2000.000000      1
# 1             1         1               1  female  1984.000000      1
# 2             2         1               3  female  1996.000000      0
# 3             3         1               1  female  1987.000000      1
# 4             4         0               3    male  1987.000000      0
# ..          ...       ...             ...     ...          ...    ...
# 886         886         0               2    male  1995.000000      0
# 887         887         1               1  female  2003.000000      0
# 888         888         0               3  female  1992.300882      1
# 889         889         1               1    male  1996.000000      0
# 890         890         0               3    male  1990.000000      0
#
#      Пергамент             Билет            Стоимость     Купе Погружены
# ...
